# %% [markdown]
# <div style="text-align: center;">
# <h1>The University of North Carolina at Chapel Hill</h1>
# <h1>Comp 521 Files and Databases - Fall 2016</h1>
# <h1 style="font-size: 250%;">Problem Set #4</h1>
# <h1 style="font-size: 200%;">Version 1.0</h1>
# <h1>Issued Wednesday 11/02/2016; Due Monday 11/14/2016</h1>
# </div>
#
# **Homework Information:** The answer cells in this notebook contain metadata that enable it to be automatically parsed. Thus, you must enter your answers *only* into the cells provided. Do not delete any answer cell and/or add a new one to replace it. If you do so by accident, download a new copy of the problem set's notebook and transfer your answers into it. You can introduce new 'coding' cells in an effort to test your approaches to problems, however, these introduced cells will not be considered when grading.
#
# Finally, some of the problems are probably too long to be done the night before the due date, so plan accordingly. Late problem sets will be penalized by a factor of 70.71% for each class meeting after their due date. Feel free to get help from others, but the work you submit in should be your own.

# %%
# Fill in the fields as described
class Student:
    first = "Calvin"
    last = "Barker"
    onyen = "barkerc1"
    pid = "720391993"

# %% [markdown]
# ---
# **Problem 1:** Using the <a href="http://csbio.unc.edu/mcmillan/Media/movies.db" download>movies</a> database from problem set #2, write a Python function to print filmographies of all of the actors from a given **movie title**. The format of your output should be:
#
#     Actor1.name,
#        Movie1.title, Movie1.release
#        Movie2.title, Movie2.release
#        Movie3.title, Movie3.release
#        Movie4.title, Movie4.release
#            .
#            .
#            .
#     Actor2.name,
#        Movie1.title, Movie1.release
#        Movie2.title, Movie2.release
#        Movie3.title, Movie3.release
#        Movie4.title, Movie4.release
#            .
#            .
#            .
#
# Where Actor1, Actor2, are all members of the cast in the given **movie title**, which should appear in all of their filmographies.

# %%
import sqlite3, pandas

def castMembers(str):
    cast = sqlite3.connect("movies.db")
    cur = cast.cursor()
    cur1 = cast.cursor()
        
    cur.execute("""SELECT C.aid, A.name 
                FROM Cast C JOIN Movies M on C.mid = M.mid JOIN Actors A on A.aid = C.aid
                WHERE M.title LIKE ?""", (str, ))
    
#    aidArr = {}
#    actors = {}
    for row in cur:
        aid = row[0]
        print(row[1])
        cur1.execute("""SELECT M.title, M.release
                    FROM Movies M JOIN Cast C on M.mid = C.mid
                    WHERE C.aid LIKE ?""", (aid, ))
        for row1 in cur1:
            title = row1[0]
            #print(title)
            release = row1[1]
            #print release
            prtStr = "  ?, ?", (title, release)
            print(prtStr)
#            actors[aidArr[aid]].append(row)
        
        
#        aidArr[row[0]] = row[1]
#        actors[row[1]] = []
    
    
#    for aid in aidArr:
#        cur.execute("""SELECT M.title, M.release
#                    FROM Movies M JOIN Cast C on M.mid = C.mid
#                    WHERE C.aid LIKE ?""", (aid, ))
#        for row in cur:
#            actors[aidArr[aid]].append(row)

        
#    return actors

#pandas.DataFrame(castMembers('test'))
castMembers('Blade Runner')
# Out:
# Harrison Ford
# Star Wars
# 1977-03-20
# ('  ?, ?', (u'Star Wars', u'1977-03-20'))
# Apocalypse Now
# 1979-08-15
# ('  ?, ?', (u'Apocalypse Now', u'1979-08-15'))
# Blade Runner
# 1982-06-25
# ('  ?, ?', (u'Blade Runner', u'1982-06-25'))
# Raiders of the Lost Ark
# 1981-06-12
# ('  ?, ?', (u'Raiders of the Lost Ark', u'1981-06-12'))
# Indiana Jones and the Temple of Doom
# 1984-05-23
# ('  ?, ?', (u'Indiana Jones and the Temple of Doom', u'1984-05-23'))
# Indiana Jones and the Last Crusade
# 1989-05-24
# ('  ?, ?', (u'Indiana Jones and the Last Crusade', u'1989-05-24'))
# Indiana Jones and the Kingdom of the Crystal Skull
# 2008-05-21
# ('  ?, ?', (u'Indiana Jones and the Kingdom of the Crystal Skull', u'2008-05-21'))
# The Conversation
# 1974-04-07
# ('  ?, ?', (u'The Conversation', u'1974-04-07'))
# American Graffiti
# 1973-08-01
# ('  ?, ?', (u'American Graffiti', u'1973-08-01'))
# The Empire Strikes Back
# 1980-01-01
# ('  ?, ?', (u'The Empire Strikes Back', u'1980-01-01'))
# Return of the Jedi
# 1983-05-23
# ('  ?, ?', (u'Return of the Jedi', u'1983-05-23'))
# What Lies Beneath
# 2000-07-21
# ('  ?, ?', (u'What Lies Beneath', u'2000-07-21'))
# Zabriskie Point
# 1970-02-09
# ('  ?, ?', (u'Zabriskie Point', u'1970-02-09'))
# Working Girl
# 1988-12-20
# ('  ?, ?', (u'Working Girl', u'1988-12-20'))
# The Devil's Own
# 1997-03-12
# ('  ?, ?', (u"The Devil's Own", u'1997-03-12'))
# A Time for Killing
# 1967-08-01
# ('  ?, ?', (u'A Time for Killing', u'1967-08-01'))
# The Fugitive
# 1993-08-06
# ('  ?, ?', (u'The Fugitive', u'1993-08-06'))
# Six Days Seven Nights
# 1998-06-12
# ('  ?, ?', (u'Six Days Seven Nights', u'1998-06-12'))
# K-19: The Widowmaker
# 2002-07-19
# ('  ?, ?', (u'K-19: The Widowmaker', u'2002-07-19'))
# Witness
# 1985-02-08
# ('  ?, ?', (u'Witness', u'1985-02-08'))
# Clear and Present Danger
# 1994-08-03
# ('  ?, ?', (u'Clear and Present Danger', u'1994-08-03'))
# Firewall
# 2006-02-10
# ('  ?, ?', (u'Firewall', u'2006-02-10'))
# Air Force One
# 1997-07-23
# ('  ?, ?', (u'Air Force One', u'1997-07-23'))
# Patriot Games
# 1992-06-04
# ('  ?, ?', (u'Patriot Games', u'1992-06-04'))
# Frantic
# 1988-02-16
# ('  ?, ?', (u'Frantic', u'1988-02-16'))
# Presumed Innocent
# 1990-07-26
# ('  ?, ?', (u'Presumed Innocent', u'1990-07-26'))
# The Mosquito Coast
# 1986-11-26
# ('  ?, ?', (u'The Mosquito Coast', u'1986-11-26'))
# Hollywood Homicide
# 2003-06-09
# ('  ?, ?', (u'Hollywood Homicide', u'2003-06-09'))
# Sabrina
# 1995-12-15
# ('  ?, ?', (u'Sabrina', u'1995-12-15'))
# Crossing Over
# 2009-02-27
# ('  ?, ?', (u'Crossing Over', u'2009-02-27'))
# The Frisco Kid
# 1979-07-06
# ('  ?, ?', (u'The Frisco Kid', u'1979-07-06'))
# Force 10 from Navarone
# 1978-11-01
# ('  ?, ?', (u'Force 10 from Navarone', u'1978-11-01'))
# Brüno
# 2009-07-08
# ('  ?, ?', (u'Br\xfcno', u'2009-07-08'))
# Hanover Street
# 1979-05-18
# ('  ?, ?', (u'Hanover Street', u'1979-05-18'))
# Extraordinary Measures
# 2010-01-21
# ('  ?, ?', (u'Extraordinary Measures', u'2010-01-21'))
# More American Graffiti
# 1979-08-03
# ('  ?, ?', (u'More American Graffiti', u'1979-08-03'))
# Morning Glory
# 2010-01-12
# ('  ?, ?', (u'Morning Glory', u'2010-01-12'))
# Getting Straight
# 1970-05-13
# ('  ?, ?', (u'Getting Straight', u'1970-05-13'))
# Cowboys & Aliens
# 2011-07-29
# ('  ?, ?', (u'Cowboys & Aliens', u'2011-07-29'))
# The Star Wars Holiday Special
# 1978-12-01
# ('  ?, ?', (u'The Star Wars Holiday Special', u'1978-12-01'))
# Ender's Game
# 2013-10-23
# ('  ?, ?', (u"Ender's Game", u'2013-10-23'))
# 42
# 2013-04-12
# ('  ?, ?', (u'42', u'2013-04-12'))
# Anchorman 2: The Legend Continues
# 2013-12-18
# ('  ?, ?', (u'Anchorman 2: The Legend Continues', u'2013-12-18'))
# Paranoia
# 2013-08-14
# ('  ?, ?', (u'Paranoia', u'2013-08-14'))
# The Expendables 3
# 2014-08-04
# ('  ?, ?', (u'The Expendables 3', u'2014-08-04'))
# Star Wars: The Force Awakens
# 2015-12-15
# ('  ?, ?', (u'Star Wars: The Force Awakens', u'2015-12-15'))
# The Age of Adaline
# 2015-04-16
# ('  ?, ?', (u'The Age of Adaline', u'2015-04-16'))
# Rutger Hauer
# Blade Runner
# 1982-06-25
# ('  ?, ?', (u'Blade Runner', u'1982-06-25'))
# Knockin' on Heaven's Door
# 1997-02-20
# ('  ?, ?', (u"Knockin' on Heaven's Door", u'1997-02-20'))
# Sin City
# 2005-03-31
# ('  ?, ?', (u'Sin City', u'2005-03-31'))
# Batman Begins
# 2005-06-14
# ('  ?, ?', (u'Batman Begins', u'2005-06-14'))
# Ladyhawke
# 1985-04-03
# ('  ?, ?', (u'Ladyhawke', u'1985-04-03'))
# Wedlock
# 1991-05-10
# ('  ?, ?', (u'Wedlock', u'1991-05-10'))
# Confessions of a Dangerous Mind
# 2002-12-30
# ('  ?, ?', (u'Confessions of a Dangerous Mind', u'2002-12-30'))
# The Wilby Conspiracy
# 1975-02-01
# ('  ?, ?', (u'The Wilby Conspiracy', u'1975-02-01'))
# The Hitcher
# 1986-02-21
# ('  ?, ?', (u'The Hitcher', u'1986-02-21'))
# The Osterman Weekend
# 1983-10-14
# ('  ?, ?', (u'The Osterman Weekend', u'1983-10-14'))
# Flesh + Blood
# 1985-08-30
# ('  ?, ?', (u'Flesh + Blood', u'1985-08-30'))
# Split Second
# 1992-05-01
# ('  ?, ?', (u'Split Second', u'1992-05-01'))
# Blind Fury
# 1989-08-17
# ('  ?, ?', (u'Blind Fury', u'1989-08-17'))
# Turkish Delight
# 1973-02-22
# ('  ?, ?', (u'Turkish Delight', u'1973-02-22'))
# Nighthawks
# 1981-03-17
# ('  ?, ?', (u'Nighthawks', u'1981-03-17'))
# Escape from Sobibor
# 1987-04-12
# ('  ?, ?', (u'Escape from Sobibor', u'1987-04-12'))
# Eureka
# 1983-05-01
# ('  ?, ?', (u'Eureka', u'1983-05-01'))
# Spetters
# 1980-02-28
# ('  ?, ?', (u'Spetters', u'1980-02-28'))
# Katie Tippel
# 1975-03-06
# ('  ?, ?', (u'Katie Tippel', u'1975-03-06'))
# The Rite
# 2011-01-28
# ('  ?, ?', (u'The Rite', u'2011-01-28'))
# Hobo with a Shotgun
# 2011-05-06
# ('  ?, ?', (u'Hobo with a Shotgun', u'2011-05-06'))
# The Scorpion King 4: Quest for Power
# 2015-01-09
# ('  ?, ?', (u'The Scorpion King 4: Quest for Power', u'2015-01-09'))
# Sean Young
# Blade Runner
# 1982-06-25
# ('  ?, ?', (u'Blade Runner', u'1982-06-25'))
# Dune
# 1984-12-14
# ('  ?, ?', (u'Dune', u'1984-12-14'))
# Ace Ventura: Pet Detective
# 1994-02-04
# ('  ?, ?', (u'Ace Ventura: Pet Detective', u'1994-02-04'))
# No Way Out
# 1987-08-14
# ('  ?, ?', (u'No Way Out', u'1987-08-14'))
# Wall Street
# 1987-12-10
# ('  ?, ?', (u'Wall Street', u'1987-12-10'))
# Stripes
# 1981-06-25
# ('  ?, ?', (u'Stripes', u'1981-06-25'))
# Jug Face
# 2013-08-09
# ('  ?, ?', (u'Jug Face', u'2013-08-09'))
# Bone Tomahawk
# 2015-10-23
# ('  ?, ?', (u'Bone Tomahawk', u'2015-10-23'))
# Edward James Olmos
# Blade Runner
# 1982-06-25
# ('  ?, ?', (u'Blade Runner', u'1982-06-25'))
# 12 Angry Men
# 1997-08-17
# ('  ?, ?', (u'12 Angry Men', u'1997-08-17'))
# Beverly Hills Chihuahua
# 2008-10-03
# ('  ?, ?', (u'Beverly Hills Chihuahua', u'2008-10-03'))
# The Green Hornet
# 2011-01-12
# ('  ?, ?', (u'The Green Hornet', u'2011-01-12'))
# Battlestar Galactica: Razor
# 2007-11-24
# ('  ?, ?', (u'Battlestar Galactica: Razor', u'2007-11-24'))
# Battlestar Galactica: The Plan
# 2009-10-27
# ('  ?, ?', (u'Battlestar Galactica: The Plan', u'2009-10-27'))
# 2 Guns
# 2013-08-02
# ('  ?, ?', (u'2 Guns', u'2013-08-02'))
# Daryl Hannah
# Kill Bill: Vol. 1
# 2003-10-10
# ('  ?, ?', (u'Kill Bill: Vol. 1', u'2003-10-10'))
# Blade Runner
# 1982-06-25
# ('  ?, ?', (u'Blade Runner', u'1982-06-25'))
# Kill Bill: Vol. 2
# 2004-04-16
# ('  ?, ?', (u'Kill Bill: Vol. 2', u'2004-04-16'))
# Splash
# 1984-03-08
# ('  ?, ?', (u'Splash', u'1984-03-08'))
# Memoirs of an Invisible Man
# 1992-02-28
# ('  ?, ?', (u'Memoirs of an Invisible Man', u'1992-02-28'))
# Legal Eagles
# 1986-06-18
# ('  ?, ?', (u'Legal Eagles', u'1986-06-18'))
# Wall Street
# 1987-12-10
# ('  ?, ?', (u'Wall Street', u'1987-12-10'))
# Steel Magnolias
# 1989-11-15
# ('  ?, ?', (u'Steel Magnolias', u'1989-11-15'))
# Grumpy Old Men
# 1993-12-25
# ('  ?, ?', (u'Grumpy Old Men', u'1993-12-25'))
# Crimes and Misdemeanors
# 1989-10-13
# ('  ?, ?', (u'Crimes and Misdemeanors', u'1989-10-13'))
# Roxanne
# 1987-06-19
# ('  ?, ?', (u'Roxanne', u'1987-06-19'))
# The Gingerbread Man
# 1998-01-23
# ('  ?, ?', (u'The Gingerbread Man', u'1998-01-23'))
# The Fury
# 1978-03-10
# ('  ?, ?', (u'The Fury', u'1978-03-10'))
# Grumpier Old Men
# 1995-12-22
# ('  ?, ?', (u'Grumpier Old Men', u'1995-12-22'))
# Final Days of Planet Earth
# 2006-03-15
# ('  ?, ?', (u'Final Days of Planet Earth', u'2006-03-15'))
# Summer Lovers
# 1982-07-16
# ('  ?, ?', (u'Summer Lovers', u'1982-07-16'))
# High Spirits
# 1988-11-18
# ('  ?, ?', (u'High Spirits', u'1988-11-18'))
# William Sanderson
# Blade Runner
# 1982-06-25
# ('  ?, ?', (u'Blade Runner', u'1982-06-25'))
# Last Man Standing
# 1996-09-20
# ('  ?, ?', (u'Last Man Standing', u'1996-09-20'))
# Fletch
# 1985-05-31
# ('  ?, ?', (u'Fletch', u'1985-05-31'))
# The Rocketeer
# 1991-06-21
# ('  ?, ?', (u'The Rocketeer', u'1991-06-21'))
# Lone Wolf McQuade
# 1983-04-14
# ('  ?, ?', (u'Lone Wolf McQuade', u'1983-04-14'))
# Coal Miner's Daughter
# 1980-03-07
# ('  ?, ?', (u"Coal Miner's Daughter", u'1980-03-07'))
# City Heat
# 1984-12-05
# ('  ?, ?', (u'City Heat', u'1984-12-05'))
# Death Hunt
# 1981-05-22
# ('  ?, ?', (u'Death Hunt', u'1981-05-22'))
# Sometimes They Come Back
# 1991-05-07
# ('  ?, ?', (u'Sometimes They Come Back', u'1991-05-07'))
# The Onion Field
# 1979-09-09
# ('  ?, ?', (u'The Onion Field', u'1979-09-09'))
# Black Moon Rising
# 1986-01-10
# ('  ?, ?', (u'Black Moon Rising', u'1986-01-10'))
# A Merry Friggin' Christmas
# 2014-11-07
# ('  ?, ?', (u"A Merry Friggin' Christmas", u'2014-11-07'))
# Brion James
# The Fifth Element
# 1997-05-07
# ('  ?, ?', (u'The Fifth Element', u'1997-05-07'))
# Blade Runner
# 1982-06-25
# ('  ?, ?', (u'Blade Runner', u'1982-06-25'))
# 48 Hrs.
# 1982-12-07
# ('  ?, ?', (u'48 Hrs.', u'1982-12-07'))
# Armed and Dangerous
# 1986-08-15
# ('  ?, ?', (u'Armed and Dangerous', u'1986-08-15'))
# Red Heat
# 1988-06-17
# ('  ?, ?', (u'Red Heat', u'1988-06-17'))
# Tango & Cash
# 1989-12-22
# ('  ?, ?', (u'Tango & Cash', u'1989-12-22'))
# The Player
# 1992-04-03
# ('  ?, ?', (u'The Player', u'1992-04-03'))
# Another 48 Hrs.
# 1990-06-08
# ('  ?, ?', (u'Another 48 Hrs.', u'1990-06-08'))
# Enemy Mine
# 1985-12-12
# ('  ?, ?', (u'Enemy Mine', u'1985-12-12'))
# Southern Comfort
# 1981-09-25
# ('  ?, ?', (u'Southern Comfort', u'1981-09-25'))
# Red Scorpion
# 1989-01-05
# ('  ?, ?', (u'Red Scorpion', u'1989-01-05'))
# Flesh + Blood
# 1985-08-30
# ('  ?, ?', (u'Flesh + Blood', u'1985-08-30'))
# Crimewave
# 1985-09-19
# ('  ?, ?', (u'Crimewave', u'1985-09-19'))
# Nemesis
# 1992-12-26
# ('  ?, ?', (u'Nemesis', u'1992-12-26'))
# Joe Turkel
# Blade Runner
# 1982-06-25
# ('  ?, ?', (u'Blade Runner', u'1982-06-25'))
# The Shining
# 1980-05-22
# ('  ?, ?', (u'The Shining', u'1980-05-22'))
# The Sand Pebbles
# 1966-12-20
# ('  ?, ?', (u'The Sand Pebbles', u'1966-12-20'))
# The Hindenburg
# 1975-12-25
# ('  ?, ?', (u'The Hindenburg', u'1975-12-25'))
# King Rat
# 1965-10-27
# ('  ?, ?', (u'King Rat', u'1965-10-27'))
# The St. Valentine's Day Massacre
# 1967-06-30
# ('  ?, ?', (u"The St. Valentine's Day Massacre", u'1967-06-30'))
# Joanna Cassidy
# Blade Runner
# 1982-06-25
# ('  ?, ?', (u'Blade Runner', u'1982-06-25'))
# Who Framed Roger Rabbit
# 1988-06-21
# ('  ?, ?', (u'Who Framed Roger Rabbit', u'1988-06-21'))
# The Fourth Protocol
# 1987-08-28
# ('  ?, ?', (u'The Fourth Protocol', u'1987-08-28'))
# Stay Hungry
# 1976-04-23
# ('  ?, ?', (u'Stay Hungry', u'1976-04-23'))
# Ghosts of Mars
# 2001-08-24
# ('  ?, ?', (u'Ghosts of Mars', u'2001-08-24'))
# Chain Reaction
# 1996-08-02
# ('  ?, ?', (u'Chain Reaction', u'1996-08-02'))
# Under Fire
# 1983-10-21
# ('  ?, ?', (u'Under Fire', u'1983-10-21'))
# Don't Tell Mom the Babysitter's Dead
# 1991-06-07
# ('  ?, ?', (u"Don't Tell Mom the Babysitter's Dead", u'1991-06-07'))
# The Outfit
# 1973-10-01
# ('  ?, ?', (u'The Outfit', u'1973-10-01'))
# The Package
# 1989-08-25
# ('  ?, ?', (u'The Package', u'1989-08-25'))
# Stunts
# 1977-06-01
# ('  ?, ?', (u'Stunts', u'1977-06-01'))
# Carjacked
# 2011-11-22
# ('  ?, ?', (u'Carjacked', u'2011-11-22'))
# Bank Shot
# 1974-07-31
# ('  ?, ?', (u'Bank Shot', u'1974-07-31'))
# James Hong
# Blade Runner
# 1982-06-25
# ('  ?, ?', (u'Blade Runner', u'1982-06-25'))
# Hero
# 2002-12-19
# ('  ?, ?', (u'Hero', u'2002-12-19'))
# Chinatown
# 1974-06-20
# ('  ?, ?', (u'Chinatown', u'1974-06-20'))
# Breathless
# 1983-05-13
# ('  ?, ?', (u'Breathless', u'1983-05-13'))
# The Sand Pebbles
# 1966-12-20
# ('  ?, ?', (u'The Sand Pebbles', u'1966-12-20'))
# Big Trouble in Little China
# 1986-05-30
# ('  ?, ?', (u'Big Trouble in Little China', u'1986-05-30'))
# The Shadow
# 1994-07-01
# ('  ?, ?', (u'The Shadow', u'1994-07-01'))
# Wayne's World 2
# 1993-12-10
# ('  ?, ?', (u"Wayne's World 2", u'1993-12-10'))
# Tank Girl
# 1995-03-31
# ('  ?, ?', (u'Tank Girl', u'1995-03-31'))
# Kung Fu Panda
# 2008-06-04
# ('  ?, ?', (u'Kung Fu Panda', u'2008-06-04'))
# Tango & Cash
# 1989-12-22
# ('  ?, ?', (u'Tango & Cash', u'1989-12-22'))
# The Golden Child
# 1986-12-12
# ('  ?, ?', (u'The Golden Child', u'1986-12-12'))
# The Day the Earth Stood Still
# 2008-12-10
# ('  ?, ?', (u'The Day the Earth Stood Still', u'2008-12-10'))
# Mulan
# 1998-06-18
# ('  ?, ?', (u'Mulan', u'1998-06-18'))
# Missing in Action
# 1984-11-16
# ('  ?, ?', (u'Missing in Action', u'1984-11-16'))
# Revenge of the Nerds II: Nerds in Paradise
# 1987-07-10
# ('  ?, ?', (u'Revenge of the Nerds II: Nerds in Paradise', u'1987-07-10'))
# The In-Laws
# 1979-06-15
# ('  ?, ?', (u'The In-Laws', u'1979-06-15'))
# Flower Drum Song
# 1961-11-09
# ('  ?, ?', (u'Flower Drum Song', u'1961-11-09'))
# Ninja III: The Domination
# 1984-09-14
# ('  ?, ?', (u'Ninja III: The Domination', u'1984-09-14'))
# Go Tell the Spartans
# 1978-07-12
# ('  ?, ?', (u'Go Tell the Spartans', u'1978-07-12'))
# True Confessions
# 1981-09-22
# ('  ?, ?', (u'True Confessions', u'1981-09-22'))
# The Two Jakes
# 1990-08-10
# ('  ?, ?', (u'The Two Jakes', u'1990-08-10'))
# Bound for Glory
# 1976-12-05
# ('  ?, ?', (u'Bound for Glory', u'1976-12-05'))
# Kung Fu Panda 2
# 2011-05-25
# ('  ?, ?', (u'Kung Fu Panda 2', u'2011-05-25'))
# R.I.P.D.
# 2013-07-18
# ('  ?, ?', (u'R.I.P.D.', u'2013-07-18'))
# Safe
# 2012-04-16
# ('  ?, ?', (u'Safe', u'2012-04-16'))
# The Hawaiians
# 1970-06-17
# ('  ?, ?', (u'The Hawaiians', u'1970-06-17'))
# Kung Fu Panda 3
# 2016-01-23
# ('  ?, ?', (u'Kung Fu Panda 3', u'2016-01-23'))
# Morgan Paull
# Blade Runner
# 1982-06-25
# ('  ?, ?', (u'Blade Runner', u'1982-06-25'))
# Patton
# 1970-01-25
# ('  ?, ?', (u'Patton', u'1970-01-25'))
# Cahill U.S. Marshal
# 1973-07-11
# ('  ?, ?', (u'Cahill U.S. Marshal', u'1973-07-11'))
# Norma Rae
# 1979-03-02
# ('  ?, ?', (u'Norma Rae', u'1979-03-02'))
# The Swarm
# 1978-07-14
# ('  ?, ?', (u'The Swarm', u'1978-07-14'))
# Kevin Thompson
# Blade Runner
# 1982-06-25
# ('  ?, ?', (u'Blade Runner', u'1982-06-25'))
# The Ewok Adventure
# 1984-11-25
# ('  ?, ?', (u'The Ewok Adventure', u'1984-11-25'))
# Return of the Jedi
# 1983-05-23
# ('  ?, ?', (u'Return of the Jedi', u'1983-05-23'))
# John Edward Allen
# Blade Runner
# 1982-06-25
# ('  ?, ?', (u'Blade Runner', u'1982-06-25'))
# Hy Pyke
# Blade Runner
# 1982-06-25
# ('  ?, ?', (u'Blade Runner', u'1982-06-25'))
# Kimiko Hiroshige
# Blade Runner
# 1982-06-25
# ('  ?, ?', (u'Blade Runner', u'1982-06-25'))
# Carolyn DeMirjian
# Blade Runner
# 1982-06-25
# ('  ?, ?', (u'Blade Runner', u'1982-06-25'))
# Bob Okazaki
# Blade Runner
# 1982-06-25
# ('  ?, ?', (u'Blade Runner', u'1982-06-25'))
# M. Emmet Walsh
# Blade Runner
# 1982-06-25
# ('  ?, ?', (u'Blade Runner', u'1982-06-25'))
# Brubaker
# 1980-06-20
# ('  ?, ?', (u'Brubaker', u'1980-06-20'))
# A Time to Kill
# 1996-07-24
# ('  ?, ?', (u'A Time to Kill', u'1996-07-24'))
# Escape from the Planet of the Apes
# 1971-05-20
# ('  ?, ?', (u'Escape from the Planet of the Apes', u'1971-05-20'))
# Critters
# 1986-04-11
# ('  ?, ?', (u'Critters', u'1986-04-11'))
# The Jerk
# 1979-12-14
# ('  ?, ?', (u'The Jerk', u'1979-12-14'))
# What's Up, Doc?
# 1972-03-09
# ('  ?, ?', (u"What's Up, Doc?", u'1972-03-09'))
# Airport '77
# 1977-03-11
# ('  ?, ?', (u"Airport '77", u'1977-03-11'))
# Wild Wild West
# 1999-06-29
# ('  ?, ?', (u'Wild Wild West', u'1999-06-29'))
# My Best Friend's Wedding
# 1997-06-19
# ('  ?, ?', (u"My Best Friend's Wedding", u'1997-06-19'))
# Harry and the Hendersons
# 1987-06-05
# ('  ?, ?', (u'Harry and the Hendersons', u'1987-06-05'))
# Serpico
# 1973-12-05
# ('  ?, ?', (u'Serpico', u'1973-12-05'))
# Free Willy 2 - The Adventure Home
# 1995-07-19
# ('  ?, ?', (u'Free Willy 2 - The Adventure Home', u'1995-07-19'))
# Fletch
# 1985-05-31
# ('  ?, ?', (u'Fletch', u'1985-05-31'))
# The Iron Giant
# 1999-08-06
# ('  ?, ?', (u'The Iron Giant', u'1999-08-06'))
# Little Big Man
# 1970-12-14
# ('  ?, ?', (u'Little Big Man', u'1970-12-14'))
# Blood Simple
# 1984-09-07
# ('  ?, ?', (u'Blood Simple', u'1984-09-07'))
# Slap Shot
# 1977-02-25
# ('  ?, ?', (u'Slap Shot', u'1977-02-25'))
# Snow Dogs
# 2002-01-18
# ('  ?, ?', (u'Snow Dogs', u'2002-01-18'))
# Silkwood
# 1983-12-14
# ('  ?, ?', (u'Silkwood', u'1983-12-14'))
# Red Scorpion
# 1989-01-05
# ('  ?, ?', (u'Red Scorpion', u'1989-01-05'))
# Big Stan
# 2007-06-06
# ('  ?, ?', (u'Big Stan', u'2007-06-06'))
# Missing in Action
# 1984-11-16
# ('  ?, ?', (u'Missing in Action', u'1984-11-16'))
# Back to School
# 1986-06-13
# ('  ?, ?', (u'Back to School', u'1986-06-13'))
# Ordinary People
# 1980-09-19
# ('  ?, ?', (u'Ordinary People', u'1980-09-19'))
# Reds
# 1981-12-25
# ('  ?, ?', (u'Reds', u'1981-12-25'))
# Youth in Revolt
# 2009-09-11
# ('  ?, ?', (u'Youth in Revolt', u'2009-09-11'))
# Wildcats
# 1986-02-14
# ('  ?, ?', (u'Wildcats', u'1986-02-14'))
# The Odd Life of Timothy Green
# 2012-08-15
# ('  ?, ?', (u'The Odd Life of Timothy Green', u'2012-08-15'))
# The Scorpion King 4: Quest for Power
# 2015-01-09
# ('  ?, ?', (u'The Scorpion King 4: Quest for Power', u'2015-01-09'))

# %% [markdown]
# ---
# ** Problem 2:** Use Jupyter's [*%timeit*](http://ipython.readthedocs.io/en/stable/interactive/magics.html#magic-timeit) function to time the function that you wrote for the movie "Blade Runner".

# %%
#Enter your Python 2 code here

# %% [raw]
# Copy the output of your %timeit here

# %% [markdown]
# ---
# **Problem 3:** Write Python code to build an index on the Cast relation of movies.db with the search key (aid, mid). Then rerun your function from Problem #2 for "Blade Runner" using *%timeit*.

# %%
#Enter Python 2 code to build your index here followed by the %timeit command

# %% [raw]
# Copy the output of  %timeit here

# %% [markdown]
# ---
# Suppose that a certain relation has 250,000 records and a B<sup>+</sup>-tree index is built on it with 24 keys per node, both leaf and interior.
#
# **Problem 4:** Assume that the records are loaded using a bulk-loader that fills each node, with the possible exception of the root, to at least 2/3 of its capacity. How many levels will be in the final tree? How many interior *steering* nodes will the tree have?

# %% [raw]
# Levels: 5
# Steering Nodes: 14425

# %% [markdown]
# **Problem 5:** Assume that the records were loaded via a series of insertions and deletions that resulted in a B<sup>+</sup>-tree where as many nodes as possible arefilled to their maximum capacity. How many levels will be in this tree? How many interior *steering* nodes will this tree have?

# %% [raw]
# Levels: 4
# Steering Nodes: 601

# %% [markdown]
# **Problem 6:** Assume that the records were loaded via a series of insertions
# and deletions that resulted in a B<sup>+</sup>-tree where <i>every</i> node is filled to its minimum capacity. How many levels will be in this tree? How many interior *steering* nodes will this tree have?</p>

# %% [raw]
# Levels: 5
# Steering Nodes: 14425

# %% [markdown]
# Consider the tree shown below:
#
# <div align="center"><img title="comp521f10pset4p1tree.png" src="http://csbio.unc.edu/mcmillan/Media/comp521PS4Tree.png" width="509" height="109" />
# </div>
#
# **Problem 7:** Suppose this is an ISAM tree.
# How many leaf nodes will have overflow pages after inserting the
# following elements: (16, 17, 18) and then deleting the elements: (11, 12, 16)?</p>

# %% [raw]
# 1

# %% [markdown]
# **Problem 8:** Suppose this is a B+ tree.
# Consider the resulting tree after inserting the following elements (16, 17, 18).
# What will be the contents of the right-most non-leaf (interior) node?

# %% [raw]
# 17

# %% [markdown]
# ---
# Use the following simple hashing function, key = aid % 1024, to build indexes
# for the *Actors* and *Cast* tables of the movies.db database using Python.
# Use your indexes to answer the following questions.
#
# **Problem 9:** What is the occupancy of (number of records in) the largest, smallest, and average bucket of the *Actors* hash index *aid*?</p>

# %% [raw]
# Largest:
# Smallest:
# Average:

# %% [markdown]
# **Problem 10:** What is the occupancy of (number of records in) the largest, smallest, and average bucket of the *Cast* hash index on *aid*?</p>

# %% [raw]
# Largest:
# Smallest:
# Average:

# %% [markdown]
# **Problem 11:** Using your indices estimate the number of tests used when joining Actors and Roles in a query such as the following:</p>
# <pre>
#     SELECT A.name, C.role
#     FROM Actors A, Cast C
#     WHERE A.aid=R.aid
# </pre>

# %% [raw]
# Enter your answer here

# %% [markdown]
# **Problem 12:** Of the two relations, *Actors* and *Cast* which would benefit more by using a dynamic hashing scheme? Explain why.

# %% [raw]
# Enter your answer here

# %% [markdown]
# Click [here to submit](http://csbio.unc.edu/mcmillan/index.py?run=PS.upload) your completed problem set. **Make sure that you upload it wiht the correct problem set number!**
#
# You can submit it as many times as you would like, but only the last submitted version will be graded. If the last submission was after the due date the final score will be reduced accordingly. We do not need your database, since your Notebook should produce it.
